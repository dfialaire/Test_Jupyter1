# %%
import csv ## https://docs.python.org/fr/3.6/library/csv.html 
#################################################
def Recup_Donnees(titre_csv):
    """ Cette fonction initiale et essentielle permet de construire
        une liste de tuples contenant toutes les informations du 
        tableau par lignes. """
    Donnees=[]  ## liste de tuples pour récupérer toutes les données du fichier csv
    Ligne_Donnees=[]  ## sous liste pour créer la liste des tuples de Donnees
    with open(titre_csv, "r", encoding="utf-8") as texte:  ## Ouverture du csv en mode utf 8 pour encodage des caractères français
        Les_lignes = csv.reader(texte, delimiter=';') ## lecture de chaque ligne du fichier csv
        for ligne in Les_lignes:  ## bouclage sur chaque ligne des lignes
            for element in ligne:  ## Récupération de chaque élément de chaque ligne
                Ligne_Donnees.append(element)  ## création d'1 tuple avec tous les éléments d'1 même ligne
            Ligne_Donnees=tuple(Ligne_Donnees)  ## assurance qu'il s'agit bien d'un tuple ..?
            Donnees.append(Ligne_Donnees)  ## Ajout du tuple créé à la liste de tuple Données
            Ligne_Donnees=[]  ## Réinitialisation d'1 futur 'tuple' vide pour boucler sur la ligne suivant du tableau
    longueur_Donnees=len(Donnees)  ## Détermination de la longueurs des Données
    return Donnees,longueur_Donnees
Donnees,longueur_Donnees=Recup_Donnees("Test_layer1.csv")
print("longueur = ",longueur_Donnees)

# %%
from ipyleaflet import (
    Map, basemaps, basemap_to_tiles,
    Circle, Marker, Rectangle, LayerGroup, LayersControl,
    AwesomeIcon, Popup, ScaleControl, FullScreenControl,
    SearchControl
)
from ipywidgets import HTML
###################################
markers_genet = []
markers_bcm = []
markers_ferm = []
markers_envi = []
markers_micro = []
markers_lycee = []
markers_pharma = []
markers_cosmeto = []
markers_alim = []
# m = Map(center=(49.25112, 4.0271), zoom=15) # layers=(toner, ), 
cent = [49.25112, 4.0271] #drop.value#
zoom = 20
m = Map(center=cent, zoom=zoom)
m.add_control(FullScreenControl())
marker = Marker(icon=AwesomeIcon(name="check", marker_color='green', icon_color='darkgreen'))

m.add_control(SearchControl(
  position="topleft",
  url='https://nominatim.openstreetmap.org/search?format=json&q={s}',
  zoom=15,
  marker=marker
))


m.interact(zoom=(5,20,1))
###############################################################
for ligne in range(1,5):
    tupl=Donnees[ligne]
    li=list(tupl)
#     print(" ***** Ligne = ",ligne," ***********")
#     print()
#     print(li)
    result=li[37]
    if result !="":
    #     print(result)
    #     print(type(result))
        result=result.split(",")
        latitude=result[0]
        longitude=result[1]
        Coord = [latitude, longitude]
    #     print("latitude=",latitude)

        infos="<u>Entreprise :</u> <b>"+str(li[2])+"</b> : <br />"+str(li[0])+" : "+str(li[1])+". <br />"+str(li[32])+", "+str(li[33])+" "+str(li[34])+"<br/> --> Tel : "+str(li[35])+"<br/> --> Mail : "+str(li[43])+"<br/> --> <a target='_blank' rel='noopener noreferrer' href='"+str(li[36])+"'>Lien </a>"
    ##### https://www.flaticon.com/fr/icone-premium/laboratoire-medical_3483814?related_id=3483663&origin=search    
        if li[0] == "Lycée":
            icon = AwesomeIcon(name='fa-graduation-cap', marker_color='lightred', icon_color='black', icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483835.png?token=exp=1627657167~hmac=914e0b35ab63604b16469288e1da5c19', icon_size=[30, 30], icon_anchor=[10,10])
      # fa-graduation-cap
    # bcm --> cut ; genetique --> random ; fermentation --> hourglass-start
        if li[0] == "BCM":
            icon = AwesomeIcon(name='cut', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Génétique":
            icon = AwesomeIcon(name='random', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Fermentations":
            icon = AwesomeIcon(name='hourglass-start', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])

        if li[0] == "Microbiologie":
            icon = AwesomeIcon(name='link', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Environnement":
            icon = AwesomeIcon(name='leaf', marker_color='lightgreen', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Pharmaceutique":
            icon = AwesomeIcon(name='pills', marker_color='lightblue', icon_color='black' , icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483663.png?token=exp=1627657677~hmac=01ec1a6d6f237b1bdea0e5db5a905f46', icon_size=[30, 30], icon_anchor=[10,10])
        if li[0] == "Cosmétique":
            icon = AwesomeIcon(name='eye', marker_color='pink', icon_color='black' , icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483814.png?token=exp=1627657700~hmac=a4c57b57f1129517d16ef9af1b5306ca', icon_size=[30, 30], icon_anchor=[10,10])
        if li[0] == "Alimentaire":
            icon = AwesomeIcon(name='coffee', marker_color='orange', icon_color='black', icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483835.png?token=exp=1627657167~hmac=914e0b35ab63604b16469288e1da5c19', icon_size=[30, 30], icon_anchor=[10,10])

        mark = Marker(location=Coord, draggable=False, icon=icon, name=li[0]) # markerColor: 'green' # marker_color

        #########
        if li[0] == "Lycée":
            markers_lycee.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        ######### markers_lycee, markers_pharma, markers_alim
        if li[0] == "BCM":
            markers_bcm.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Génétique":
            markers_genet.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Fermentations":
            markers_ferm.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))   

        if li[0] == "Microbiologie":
            markers_micro.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Environnement":
            markers_envi.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Pharmaceutique":
            markers_pharma.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Cosmétique":
            markers_cosmeto.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Alimentaire":
            markers_alim.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))

        ##########################################

        message2 = HTML()
        message2.value = infos
        # Popup with a given location on the map:
        popup = Popup(
            location=Coord,
            close_button=False,
            auto_close=False,
            close_on_escape_key=False
        ) #        child=message2,

        mark.popup = message2

# cluster_lycee = MarkerCluster(markers=markers_lycee)
# cluster_ferm = MarkerCluster(markers=markers_ferm)
# cluster_bcm = MarkerCluster(markers=markers_bcm)
# cluster_genet = MarkerCluster(markers=markers_genet)

# cluster_envi = MarkerCluster(markers=markers_envi)
# cluster_micro = MarkerCluster(markers=markers_micro)
# cluster_pharma = MarkerCluster(markers=markers_pharma)
# cluster_cosmeto = MarkerCluster(markers=markers_cosmeto)
# cluster_alim = MarkerCluster(markers=markers_alim)
# m.add_layer(cluster_lycee)
# m.add_layer(cluster_bcm)
# m.add_layer(cluster_genet)
# m.add_layer(cluster_ferm)

# m.add_layer(cluster_envi)
# m.add_layer(cluster_micro)
# m.add_layer(cluster_pharma)
# m.add_layer(cluster_cosmeto)
# m.add_layer(cluster_alim)

m.add_control(ScaleControl(position='bottomleft'))
# m
#####################################################""
# Create some layers
# marker = Marker(location=(50, 354))
# circle = Circle(location=(50, 370), radius=50000, color="yellow", fill_color="yellow")
# rectangle = Rectangle(bounds=((54, 354), (55, 360)), color="orange", fill_color="orange")

# Create layer group

# list_tuple = tuple(markers_lycee, markers_pharma, markers_alim)
# print(type(list_tuple))
# print(list_tuple)
layer_group1 = LayerGroup(name = "couche1", layers=markers_lycee) # list_tuple) # marker, circle))
layer_group2 = LayerGroup(name = "couche2", layers=markers_pharma)
layer_group3 = LayerGroup(name = "couche3", layers=markers_alim)
layer_group4 = LayerGroup(name = "couche4", layers=markers_cosmeto)



m.add_layer(layer_group1)
m.add_layer(layer_group2)
m.add_layer(layer_group3)
m.add_layer(layer_group4)

# layer_group.add_layer(rectangle)

# layer_group.remove_layer(circle)
control = LayersControl(position='topleft')
m.add_control(control)

m

# %%
#######################
#######################
#######################
#######################

# %%
from ipyleaflet import (
    Map, basemaps, basemap_to_tiles,
    Circle, Marker, Rectangle, LayerGroup, LayersControl,
    AwesomeIcon, Popup, ScaleControl, FullScreenControl,
    SearchControl
)
from ipywidgets import HTML
###################################
markers_genet = []
markers_bcm = []
markers_ferm = []
markers_envi = []
markers_micro = []
markers_lycee = []
markers_pharma = []
markers_cosmeto = []
markers_alim = []
# m = Map(center=(49.25112, 4.0271), zoom=15) # layers=(toner, ), 
cent = [49.25112, 4.0271] #drop.value#
zoom = 20
m = Map(center=cent, zoom=zoom)
m.add_control(FullScreenControl())
marker = Marker(icon=AwesomeIcon(name="check", marker_color='green', icon_color='darkgreen'))

m.add_control(SearchControl(
  position="topleft",
  url='https://nominatim.openstreetmap.org/search?format=json&q={s}',
  zoom=15,
  marker=marker
))


m.interact(zoom=(5,20,1))
###############################################################
for ligne in range(1,5):
    tupl=Donnees[ligne]
    li=list(tupl)
#     print(" ***** Ligne = ",ligne," ***********")
#     print()
#     print(li)
    result=li[37]
    if result !="":
    #     print(result)
    #     print(type(result))
        result=result.split(",")
        latitude=result[0]
        longitude=result[1]
        Coord = [latitude, longitude]
    #     print("latitude=",latitude)

        infos="<u>Entreprise :</u> <b>"+str(li[2])+"</b> : <br />"+str(li[0])+" : "+str(li[1])+". <br />"+str(li[32])+", "+str(li[33])+" "+str(li[34])+"<br/> --> Tel : "+str(li[35])+"<br/> --> Mail : "+str(li[43])+"<br/> --> <a target='_blank' rel='noopener noreferrer' href='"+str(li[36])+"'>Lien </a>"
    ##### https://www.flaticon.com/fr/icone-premium/laboratoire-medical_3483814?related_id=3483663&origin=search    
        if li[0] == "Lycée":
            icon = AwesomeIcon(name='fa-graduation-cap', marker_color='lightred', icon_color='black', icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483835.png?token=exp=1627657167~hmac=914e0b35ab63604b16469288e1da5c19', icon_size=[30, 30], icon_anchor=[10,10])
      # fa-graduation-cap
    # bcm --> cut ; genetique --> random ; fermentation --> hourglass-start
        if li[0] == "BCM":
            icon = AwesomeIcon(name='cut', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Génétique":
            icon = AwesomeIcon(name='random', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Fermentations":
            icon = AwesomeIcon(name='hourglass-start', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])

        if li[0] == "Microbiologie":
            icon = AwesomeIcon(name='link', marker_color='lightgray', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Environnement":
            icon = AwesomeIcon(name='leaf', marker_color='lightgreen', icon_color='black' , icon_size=[40, 40])
        if li[0] == "Pharmaceutique":
            icon = AwesomeIcon(name='pills', marker_color='lightblue', icon_color='black' , icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483663.png?token=exp=1627657677~hmac=01ec1a6d6f237b1bdea0e5db5a905f46', icon_size=[30, 30], icon_anchor=[10,10])
        if li[0] == "Cosmétique":
            icon = AwesomeIcon(name='eye', marker_color='pink', icon_color='black' , icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483814.png?token=exp=1627657700~hmac=a4c57b57f1129517d16ef9af1b5306ca', icon_size=[30, 30], icon_anchor=[10,10])
        if li[0] == "Alimentaire":
            icon = AwesomeIcon(name='coffee', marker_color='orange', icon_color='black', icon_size=[40, 40])
    #         icon = Icon(icon_url='https://img-premium.flaticon.com/png/512/3483/3483835.png?token=exp=1627657167~hmac=914e0b35ab63604b16469288e1da5c19', icon_size=[30, 30], icon_anchor=[10,10])

        mark = Marker(location=Coord, draggable=False, icon=icon, name=li[0]) # markerColor: 'green' # marker_color

        #########
        if li[0] == "Lycée":
            markers_lycee.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        ######### markers_lycee, markers_pharma, markers_alim
        if li[0] == "BCM":
            markers_bcm.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Génétique":
            markers_genet.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Fermentations":
            markers_ferm.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))   

        if li[0] == "Microbiologie":
            markers_micro.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Environnement":
            markers_envi.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Pharmaceutique":
            markers_pharma.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Cosmétique":
            markers_cosmeto.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))
        if li[0] == "Alimentaire":
            markers_alim.append(mark) # Marker(location=(lat, lon), draggable=False, title=name, alt=name))

        ##########################################

        message2 = HTML()
        message2.value = infos
        # Popup with a given location on the map:
        popup = Popup(
            location=Coord,
            close_button=False,
            auto_close=False,
            close_on_escape_key=False
        ) #        child=message2,

        mark.popup = message2

# cluster_lycee = MarkerCluster(markers=markers_lycee)
# cluster_ferm = MarkerCluster(markers=markers_ferm)
# cluster_bcm = MarkerCluster(markers=markers_bcm)
# cluster_genet = MarkerCluster(markers=markers_genet)

# cluster_envi = MarkerCluster(markers=markers_envi)
# cluster_micro = MarkerCluster(markers=markers_micro)
# cluster_pharma = MarkerCluster(markers=markers_pharma)
# cluster_cosmeto = MarkerCluster(markers=markers_cosmeto)
# cluster_alim = MarkerCluster(markers=markers_alim)
# m.add_layer(cluster_lycee)
# m.add_layer(cluster_bcm)
# m.add_layer(cluster_genet)
# m.add_layer(cluster_ferm)

# m.add_layer(cluster_envi)
# m.add_layer(cluster_micro)
# m.add_layer(cluster_pharma)
# m.add_layer(cluster_cosmeto)
# m.add_layer(cluster_alim)

m.add_control(ScaleControl(position='bottomleft'))
# m
#####################################################""
# Create some layers
# marker = Marker(location=(50, 354))
# circle = Circle(location=(50, 370), radius=50000, color="yellow", fill_color="yellow")
# rectangle = Rectangle(bounds=((54, 354), (55, 360)), color="orange", fill_color="orange")

# Create layer group

# list_tuple = tuple(markers_lycee, markers_pharma, markers_alim)
# print(type(list_tuple))
# print(list_tuple)
layer_group1 = LayerGroup(name = "couche1", layers=markers_lycee) # list_tuple) # marker, circle))
layer_group2 = LayerGroup(name = "couche2", layers=markers_pharma)
layer_group3 = LayerGroup(name = "couche3", layers=markers_alim)
layer_group4 = LayerGroup(name = "couche4", layers=markers_cosmeto)



m.add_layer(layer_group1)
m.add_layer(layer_group2)
m.add_layer(layer_group3)
m.add_layer(layer_group4)

# layer_group.add_layer(rectangle)

# layer_group.remove_layer(circle)
control = LayersControl(position='topleft')
m.add_control(control)

m

# %%
import re
noms = []
names = ['peter', 'john', 'thomas', 'george']
long_names=len(names)
for name in range(long_names):
    nom="markers_"+names[name]
    noms.append(nom)
    
    
    #############
    
    
    
# noms = {n: [] for n in names}
print(noms)
# noms = ['markers_peter', 'markers_john', 'markers_thomas', 'markers_george']

matched = {n: [] for n in noms}
print(matched)

for name in matched:
    matched[name].append(1)

print (matched)
listo = matched[noms[0]]
print(listo)
print(type(listo))
listo.append(3)
print(listo)
print (matched)
# Out:
# ['markers_peter', 'markers_john', 'markers_thomas', 'markers_george']
# {'markers_peter': [], 'markers_john': [], 'markers_thomas': [], 'markers_george': []}

# %%
import re
names = ['peter', 'john', 'thomas', 'george']
names_marker=[]
for name in names:
    names_marker=[
matched = {n: [] for n in names}


for name in names:
    yo="markers_"+name
    print(yo)
    matched[yo].append(name)

print (matched)
listo = matched[names[0]]
print(listo)
print(type(listo))
# Out:
# markers_peter
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-0be2962f7b55> in <module>
#       8     yo="markers_"+name
#       9     print(yo)
# ---> 10     matched[yo].append(name)
#      11
#      12 print (matched)
#
# KeyError: 'markers_peter'

# %%
import re
names = ['peter', 'john', 'thomas', 'george']

matched = {"markers_"+n: [] for n in names}


for name in matched:
#     yo="markers_"+name
#     print(yo)
    matched[name].append(name)

print (matched)
list_matched=list(matched)
listo = list_matched[0]
print(listo)
print(type(listo))
# Out:
# {'markers_peter': ['markers_peter'], 'markers_john': ['markers_john'], 'markers_thomas': ['markers_thomas'], 'markers_george': ['markers_george']}
# markers_peter
# <class 'str'>
